# %% [markdown]
# The script allows to connect to database, create a table and add some values from Pandas dataframe, convert PostgreSQL table into Pandas DF

# %%
import sqlalchemy
import psycopg2
import pandas as pd

engine = sqlalchemy.create_engine('postgresql+psycopg2://USER_NAME:PASSWORD@localhost/DATABASE_NAME')

# %%
table_prepared = pd.read_csv(r"FILE_PATH")

# %%
table_prepared.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
###creates a table in PostgreSQL database

metadata = sqlalchemy.MetaData()

table = sqlalchemy.Table(
    "test_table",
    metadata,
    sqlalchemy.Column("Number", sqlalchemy.Integer, primary_key=True),
    sqlalchemy.Column("Years_of_experience", sqlalchemy.Float),
    sqlalchemy.Column("Salary", sqlalchemy.Integer)
)
metadata.create_all(engine)

# %%
###adding values into database

counter = 0

for row in range (len(table_prepared)):
    salary = table_prepared.iloc[counter,1]
    years_of_experience = table_prepared.iloc[counter,0]
    index_to_be_passed = counter
    with engine.connect() as conn:
        conn.execute(sqlalchemy.insert(table).
                     values
                     (Salary=salary,
                     Years_of_experience=years_of_experience)
                    )
        conn.commit()
    if counter % 10 == 0:
        print (f'Added {counter} rows')
    else:
        pass
    counter +=1
# Out:
# Already added 0 rows
# Already added 10 rows
# Already added 20 rows

# %%
###load PostgreSQL table into Pandas DF

postgres_table = pd.read_sql("test_table", con=engine.connect())
postgres_table.head(10)
# Out:
#    Number  Years_of_experience  Salary
# 0       1                  1.1   39343
# 1       2                  1.3   46205
# 2       3                  1.5   37731
# 3       4                  2.0   43525
# 4       5                  2.2   39891
# 5       6                  2.9   56642
# 6       7                  3.0   60150
# 7       8                  3.2   54445
# 8       9                  3.2   64445
# 9      10                  3.7   57189
